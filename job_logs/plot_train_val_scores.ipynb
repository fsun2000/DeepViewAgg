# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

colormap = mpl.cm.tab10.colors   # Qualitative colormap

# %%
plt.figure(figsize=(12,8))
for i in range(1, 7):

    with open(f'mvfusion_3d/model_comparison/M{i}.out') as f:
        lines = f.readlines()

        pattern = 'train_miou ='
        matching_lines = [line for line in lines if pattern in line]
        train_scores = [float(m.split()[-1]) for m in matching_lines]

        pattern = 'val_miou ='
        matching_lines = [line for line in lines if pattern in line]
        val_scores = [float(m.split()[-1]) for m in matching_lines]
    
        # Adjust length of lists
        train_scores = train_scores#[:69]
        val_scores = val_scores#[:13]
        
        print(sorted(train_scores, reverse=True)[:3])
        print(sorted(val_scores, reverse=True)[:3])

        plt.plot(range(len(train_scores)), train_scores, color=colormap[i], label=f'M{i}')
        plt.plot(range(4, len(train_scores) - len(train_scores) % 5, 5), val_scores, color=colormap[i])
plt.legend()
ax = plt.gca()
# ax.set_xlim([xmin, xmax])
ax.set_ylim([60, 87])

plt.show()
# Out:
# [88.51445607204363, 88.11822801399568, 87.94316127703071]
# [76.16615253444887, 76.0606838163183, 76.03332939733593]
# [87.84228631220172, 87.4922621096968, 87.21598409967535]
# [75.87297333637069, 75.68900369821272, 75.57554602966549]
# [87.92659996264949, 87.80276778813116, 87.19314581513508]
# [75.5869207093334, 75.57044052040467, 75.52153506658362]
# [87.85193883245483, 87.69228609114457, 87.67531625071253]
# [75.75615585111584, 75.52617678485285, 75.49228273754802]
# [88.61503353964963, 88.35747996470624, 87.76071217121404]
# [75.81201210164987, 75.70246034714746, 75.42526799976763]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3876/1515158197.py in <module>
#      21
#      22         plt.plot(range(len(train_scores)), train_scores, color=colormap[i], label=f'M{i}')
# ...

# %%
plt.figure(figsize=(12,8))
for i in range(1, 7):

    with open(f'mvfusion_3d/model_comparison/M{i}.out') as f:
        print(f"M{i}")
        lines = f.readlines()

        pattern = 'train_miou ='
        matching_lines = [line for line in lines if pattern in line]
        train_scores = np.array([float(m.split()[-1]) for m in matching_lines])

        pattern = 'val_miou ='
        matching_lines = [line for line in lines if pattern in line]
        val_scores = np.array([float(m.split()[-1]) for m in matching_lines])
    
        # Adjust length of lists
        idx = list(range(4, len(train_scores), 5))

        train_scores = train_scores[idx]
        

        val_scores = val_scores
        
        print(sorted(train_scores, reverse=True)[:3])
        print(sorted(val_scores, reverse=True)[:3])

        plt.plot(range(len(train_scores)), train_scores, color=colormap[i], label=f'M{i}')
        plt.plot(range(len(val_scores)), val_scores, color=colormap[i])
plt.legend()
ax = plt.gca()
# ax.set_xlim([xmin, xmax])
ax.set_ylim([60, 87])

plt.show()
# Out:
# M1
# [86.94727245742095, 86.89151293453801, 86.28183983299841]
# [76.16615253444887, 76.0606838163183, 76.03332939733593]
# M2
# [86.80579924704244, 86.58318084844578, 86.24309117137315]
# [75.87297333637069, 75.68900369821272, 75.57554602966549]
# M3
# [86.97026915918202, 86.9106371678687, 86.670329552866]
# [75.5869207093334, 75.57044052040467, 75.52153506658362]
# M4
# [86.51130212869532, 86.07452061499853, 86.02421142705221]
# [75.75615585111584, 75.52617678485285, 75.49228273754802]
# M5
# [87.76071217121404, 86.03746054928007, 85.99035885901858]
# [75.81201210164987, 75.70246034714746, 75.42526799976763]
# M6
# [86.8787163658998, 86.74648610291118, 86.34217200934587]
# [75.77596492816414, 75.60772470580473, 75.606235324248]

# %%
def plot_barchart():
        
#     N = 6
#     ind = np.arange(N) 
    width = 0.25
    bars = []
    
    for i in range(1, 7):
        plt.figure(figsize=(12,8))

        with open(f'mvfusion_3d/model_comparison/M{i}.out') as f:
            print(f"M{i}")
            lines = f.readlines()

            pattern = 'train_miou ='
            matching_lines = [line for line in lines if pattern in line]
            train_scores = np.array([float(m.split()[-1]) for m in matching_lines])

            pattern = 'val_miou ='
            matching_lines = [line for line in lines if pattern in line]
            val_scores = np.array([float(m.split()[-1]) for m in matching_lines])

            # Adjust length of lists
            idx = list(range(4, len(train_scores), 5))

            train_scores = train_scores[idx]
            val_scores = val_scores

            print(sorted(train_scores, reverse=True)[:3])
            print(sorted(val_scores, reverse=True)[:3])

#             plt.plot(range(len(train_scores)), train_scores, color=colormap[i], label=f'M{i}')
#             plt.plot(range(len(val_scores)), val_scores, color=colormap[i])
    


            xvals = val_scores[:23]
            print(xvals)
            bars.append(plt.bar(np.arange(len(xvals)) + width*(i-1), xvals, width, color=colormap[i]))

#             yvals = [10, 20, 30]
#             bar2 = plt.bar(ind+width, yvals, width, color='g')

#             zvals = [11, 12, 13]
#             bar3 = plt.bar(ind+width*2, zvals, width, color = 'b')

        plt.xlabel("Dates")
        plt.ylabel('Scores')
        plt.title("Players Score")
        plt.grid()


        plt.xticks(np.arange(len(xvals))+width,[str(i) for i in range(len(xvals))])
    #     plt.legend( (bar1, bar2, bar3), ('Player1', 'Player2', 'Player3') )

        ax = plt.gca()
        # ax.set_xlim([xmin, xmax])
        ax.set_ylim([70, 76.5])

        plt.show()
plot_barchart()
# Out:
# M1
# [86.94727245742095, 86.89151293453801, 86.28183983299841]
# [76.16615253444887, 76.0606838163183, 76.03332939733593]
# [69.17987784 72.31188578 71.83162907 73.656527   73.79400248 74.43719371
#  74.82794569 74.27855637 74.42953376 75.00531195 74.51516531 75.34041605
#  74.75266765 75.38552957 75.37786315 75.93535743 75.71781135 75.56178595
#  75.89607886 75.87960975 75.77280082 76.16615253 76.06068382]
# M2
# [86.80579924704244, 86.58318084844578, 86.24309117137315]
# [75.87297333637069, 75.68900369821272, 75.57554602966549]
# [70.0222448  72.35702247 72.08249314 73.81809152 74.03738369 73.94281331
#  74.46381599 74.05389885 74.62004393 73.51273278 74.85680394 74.73137127
#  75.57554603 75.05928723 73.8166003  75.07099742 75.35356954 74.85803775
#  75.4196806  75.22025629 73.80891478 75.6890037  74.87971518]
# M3
# [86.97026915918202, 86.9106371678687, 86.670329552866]
# [75.5869207093334, 75.57044052040467, 75.52153506658362]
# ...

# %%
def plot_barchart():
    
    plt.figure(figsize=(12,8))
    
#     N = 6
#     ind = np.arange(N) 
    width = 0.13
    bars = []
    
    for i in range(1, 7):

        with open(f'mvfusion_3d/model_comparison/M{i}.out') as f:
            print(f"M{i}")
            lines = f.readlines()

            pattern = 'train_miou ='
            matching_lines = [line for line in lines if pattern in line]
            train_scores = np.array([float(m.split()[-1]) for m in matching_lines])

            pattern = 'val_miou ='
            matching_lines = [line for line in lines if pattern in line]
            val_scores = np.array([float(m.split()[-1]) for m in matching_lines])

            # Adjust length of lists
            idx = list(range(4, 115, 5))

            train_scores = train_scores[idx]
            val_scores = val_scores

            xvals = train_scores
            bars.append(plt.bar(np.arange(len(xvals)) + width*(i-1), xvals, width, color=colormap[i]))

    plt.xlabel("Dates")
    plt.ylabel('Scores')
    plt.title("Players Score")

    plt.xticks(np.arange(len(val_scores))+width,[str(i) for i in range(len(xvals))])
#     plt.legend( (bar1, bar2, bar3), ('Player1', 'Player2', 'Player3') )
    plt.show()
    
plot_barchart()
# Out:
# M1
# M2
# M3
# M4
# M5
# M6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3876/1306999681.py in <module>
#      39     plt.show()
#      40
# ---> 41 plot_barchart()
#
# /tmp/ipykernel_3876/1306999681.py in plot_barchart()
#      35     plt.title("Players Score")
#      36
# ---> 37     plt.xticks(np.arange(len(val_scores))+width,[str(i) for i in range(len(xvals))])
#      38 #     plt.legend( (bar1, bar2, bar3), ('Player1', 'Player2', 'Player3') )
#      39     plt.show()
#
# /sw/arch/Debian10/EB_production/2021/software/matplotlib/3.4.2-foss-2021a/lib/python3.9/site-packages/matplotlib/pyplot.py in xticks(ticks, labels, **kwargs)
#    1812         labels = ax.get_xticklabels()
#    1813     else:
# -> 1814         labels = ax.set_xticklabels(labels, **kwargs)
#    1815     for l in labels:
#    1816         l.update(kwargs)
#
# ...
